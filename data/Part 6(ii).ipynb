# %%
import os

# %%
# PARTIAL dataset
# !python bert-ner_run.py --no_cuda --data_dir=partial/ --bert_model=bert-base-cased --task_name=ner --output_dir=out_ner --max_seq_length=128 --do_train --num_train_epochs 25 --warmup_proportion=0.1

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\andrehadianto\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from bert import Ner
model = Ner('out_ner/')

# %%
dataset = "test\\partial"

# %%
sentences = list()
with open(os.path.join(dataset, "test.in")) as f:
        lines = f.readlines()
        sentence = list()
        sent = ""
        for line in lines:
            formatted_line = line.strip().split(" ")
            if(len(formatted_line) <=1):
                sentences.append(sent.strip())
                sent = ""
                continue
            sent += formatted_line[0]+" " +formatted_line[1] + " "   

print(sentences[0])
            
output_filename='test.p6.model.out'
with open(os.path.join(dataset, output_filename), "w") as wf:
    for sentence in sentences:
        output = model.predict(sentence)
        for prediction in output:
            print(prediction)
            wf.write(prediction['word'] + " " + prediction['tag'] + "\n")               
        wf.write("\n")
# Out:
# Former JJ U.N. NNP Secretary NNP General NNP Kofi NNP Annan NNP had VBD called VBN for IN a DT 12-month JJ extension NN before IN leaving VBG his PRP$ post NN last JJ year NN . .
# {'word': 'Former', 'tag': 'O', 'confidence': 0.9547337889671326}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.4830361604690552}
# {'word': 'U.N.', 'tag': 'B-org', 'confidence': 0.4098471999168396}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.299051970243454}
# {'word': 'Secretary', 'tag': 'O', 'confidence': 0.7180194854736328}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.2993250787258148}
# {'word': 'General', 'tag': 'B-per', 'confidence': 0.40106484293937683}
# {'word': 'NNP', 'tag': 'I-per', 'confidence': 0.30893442034721375}
# {'word': 'Kofi', 'tag': 'I-per', 'confidence': 0.6143648624420166}
# {'word': 'NNP', 'tag': 'I-per', 'confidence': 0.2551127076148987}
# {'word': 'Annan', 'tag': 'I-per', 'confidence': 0.2811167538166046}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.37765052914619446}
# {'word': 'had', 'tag': 'O', 'confidence': 0.9965046644210815}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.5389477014541626}
# {'word': 'called', 'tag': 'O', 'confidence': 0.9968492388725281}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5604822635650635}
# {'word': 'for', 'tag': 'O', 'confidence': 0.9956522583961487}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3479975461959839}
# {'word': 'a', 'tag': 'O', 'confidence': 0.9957953691482544}
# {'word': 'DT', 'tag': 'O', 'confidence': 0.34810808300971985}
# {'word': '12-month', 'tag': 'O', 'confidence': 0.5358691811561584}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5229746699333191}
# {'word': 'extension', 'tag': 'O', 'confidence': 0.9927716851234436}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.46788936853408813}
# {'word': 'before', 'tag': 'O', 'confidence': 0.994761049747467}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3487176299095154}
# {'word': 'leaving', 'tag': 'O', 'confidence': 0.9931453466415405}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.5183542966842651}
# {'word': 'his', 'tag': 'O', 'confidence': 0.9959041476249695}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.40900930762290955}
# {'word': '$', 'tag': 'O', 'confidence': 0.9836132526397705}
# {'word': 'post', 'tag': 'O', 'confidence': 0.9950215816497803}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.46513068675994873}
# {'word': 'last', 'tag': 'O', 'confidence': 0.9739323854446411}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.41595199704170227}
# {'word': 'year', 'tag': 'O', 'confidence': 0.973008394241333}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.46557942032814026}
# {'word': '.', 'tag': 'O', 'confidence': 0.9639819860458374}
# {'word': '.', 'tag': 'O', 'confidence': 0.9921303391456604}
# {'word': 'The', 'tag': 'O', 'confidence': 0.9964168071746826}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.5006080269813538}
# {'word': 'government', 'tag': 'O', 'confidence': 0.977860689163208}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4923233091831207}
# {'word': 'also', 'tag': 'O', 'confidence': 0.9939972162246704}
# {'word': 'RB', 'tag': 'B-org', 'confidence': 0.4029443860054016}
# {'word': 'has', 'tag': 'O', 'confidence': 0.9965260624885559}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5722202658653259}
# {'word': 'suspended', 'tag': 'O', 'confidence': 0.9970571994781494}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5363144874572754}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9970410466194153}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.4415318965911865}
# {'word': 'mayors', 'tag': 'O', 'confidence': 0.9935114979743958}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.5014605522155762}
# {'word': 'of', 'tag': 'O', 'confidence': 0.996625542640686}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3215296268463135}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9942978024482727}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.40431612730026245}
# {'word': 'cities', 'tag': 'O', 'confidence': 0.9900357723236084}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.38876309990882874}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9947851300239563}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3932737112045288}
# {'word': 'Xingning', 'tag': 'B-geo', 'confidence': 0.31936463713645935}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.4239431917667389}
# {'word': 'and', 'tag': 'O', 'confidence': 0.9930718541145325}
# {'word': 'CC', 'tag': 'B-org', 'confidence': 0.33054420351982117}
# {'word': 'Meizhou', 'tag': 'B-geo', 'confidence': 0.40486252307891846}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.36188212037086487}
# {'word': 'for', 'tag': 'O', 'confidence': 0.9974391460418701}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.2911584973335266}
# {'word': 'failing', 'tag': 'O', 'confidence': 0.9957188963890076}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.525805652141571}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9970493316650391}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.894271731376648}
# {'word': 'supervise', 'tag': 'O', 'confidence': 0.994976282119751}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.5736678838729858}
# {'word': 'coal', 'tag': 'O', 'confidence': 0.9501219987869263}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.39336487650871277}
# {'word': 'mine', 'tag': 'O', 'confidence': 0.987565815448761}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.3876313269138336}
# {'word': 'production', 'tag': 'O', 'confidence': 0.9897040724754333}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.40091651678085327}
# {'word': '.', 'tag': 'O', 'confidence': 0.986653745174408}
# {'word': '.', 'tag': 'O', 'confidence': 0.9937825798988342}
# {'word': 'The', 'tag': 'O', 'confidence': 0.9974217414855957}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.4253053069114685}
# {'word': 'settlers', 'tag': 'O', 'confidence': 0.9950516819953918}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.4865293800830841}
# {'word': 'were', 'tag': 'O', 'confidence': 0.9968602657318115}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.5125802755355835}
# {'word': 'apparently', 'tag': 'O', 'confidence': 0.9969158172607422}
# {'word': 'RB', 'tag': 'O', 'confidence': 0.6250677704811096}
# {'word': 'retaliating', 'tag': 'O', 'confidence': 0.9968096613883972}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.5721563100814819}
# {'word': 'because', 'tag': 'O', 'confidence': 0.996904194355011}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3302244246006012}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9949278831481934}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.32964420318603516}
# {'word': 'army', 'tag': 'O', 'confidence': 0.9926527738571167}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4217607080936432}
# {'word': 'removed', 'tag': 'O', 'confidence': 0.9974096417427063}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.43783724308013916}
# {'word': 'a', 'tag': 'O', 'confidence': 0.9969860911369324}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.3229083716869354}
# {'word': 'settler', 'tag': 'O', 'confidence': 0.9952380657196045}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.47599345445632935}
# {'word': "'s", 'tag': 'O', 'confidence': 0.996124804019928}
# {'word': 'POS', 'tag': 'O', 'confidence': 0.5660725235939026}
# {'word': 'caravan', 'tag': 'O', 'confidence': 0.9959717392921448}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.42188310623168945}
# {'word': 'from', 'tag': 'O', 'confidence': 0.9972027540206909}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.26210254430770874}
# {'word': 'an', 'tag': 'O', 'confidence': 0.9966996312141418}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.32695484161376953}
# {'word': 'unauthorized', 'tag': 'O', 'confidence': 0.9965035915374756}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.6249483823776245}
# {'word': 'settlement', 'tag': 'O', 'confidence': 0.9965860843658447}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4703070819377899}
# {'word': 'outpost', 'tag': 'O', 'confidence': 0.9949806332588196}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.46130579710006714}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9965315461158752}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.29671409726142883}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9948097467422485}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.38362979888916016}
# {'word': 'area', 'tag': 'O', 'confidence': 0.9905440807342529}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.47328945994377136}
# {'word': 'earlier', 'tag': 'O', 'confidence': 0.9911378026008606}
# {'word': 'RBR', 'tag': 'B-org', 'confidence': 0.5716075897216797}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9954317808151245}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.2601703107357025}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9920927882194519}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.2669009864330292}
# {'word': 'day', 'tag': 'O', 'confidence': 0.9443727135658264}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4347517788410187}
# {'word': '.', 'tag': 'O', 'confidence': 0.9804423451423645}
# {'word': '.', 'tag': 'O', 'confidence': 0.9927076697349548}
# {'word': 'Interim', 'tag': 'O', 'confidence': 0.49974292516708374}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.4168805480003357}
# {'word': 'Iraqi', 'tag': 'B-gpe', 'confidence': 0.5270253419876099}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.4134594202041626}
# {'word': 'Prime', 'tag': 'B-per', 'confidence': 0.3715207278728485}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.30661600828170776}
# {'word': 'Minister', 'tag': 'B-per', 'confidence': 0.4579821527004242}
# {'word': 'NNP', 'tag': 'I-per', 'confidence': 0.39644622802734375}
# {'word': 'Iyad', 'tag': 'I-per', 'confidence': 0.7066277265548706}
# {'word': 'NNP', 'tag': 'I-per', 'confidence': 0.6125657558441162}
# {'word': 'Allawi', 'tag': 'I-per', 'confidence': 0.49031350016593933}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3994124233722687}
# {'word': 'says', 'tag': 'O', 'confidence': 0.9962448477745056}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5302208065986633}
# {'word': 'he', 'tag': 'O', 'confidence': 0.9967806339263916}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.49165183305740356}
# {'word': 'will', 'tag': 'O', 'confidence': 0.9965560436248779}
# {'word': 'MD', 'tag': 'O', 'confidence': 0.9866292476654053}
# {'word': 'more', 'tag': 'O', 'confidence': 0.996010422706604}
# {'word': 'RBR', 'tag': 'B-org', 'confidence': 0.4034801423549652}
# {'word': 'than', 'tag': 'O', 'confidence': 0.9965280890464783}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.39686691761016846}
# {'word': 'double', 'tag': 'O', 'confidence': 0.9947698712348938}
# {'word': 'VB', 'tag': 'O', 'confidence': 0.4537041187286377}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9886156916618347}
# {'word': 'DT', 'tag': 'O', 'confidence': 0.5443627238273621}
# {'word': 'size', 'tag': 'O', 'confidence': 0.9957518577575684}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.3928125500679016}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9967601895332336}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.32546141743659973}
# {'word': 'Iraq', 'tag': 'B-geo', 'confidence': 0.6249662637710571}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3486348092556}
# {'word': "'s", 'tag': 'O', 'confidence': 0.9957677125930786}
# {'word': 'POS', 'tag': 'B-org', 'confidence': 0.40625372529029846}
# {'word': 'army', 'tag': 'O', 'confidence': 0.9918346405029297}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4088912606239319}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9973033666610718}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.9806544184684753}
# {'word': '1,50,000', 'tag': 'O', 'confidence': 0.9655821323394775}
# {'word': 'CD', 'tag': 'O', 'confidence': 0.7856070399284363}
# {'word': 'troops', 'tag': 'O', 'confidence': 0.9963052272796631}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.325246125459671}
# {'word': ',', 'tag': 'O', 'confidence': 0.9960951209068298}
# {'word': ',', 'tag': 'O', 'confidence': 0.9962846040725708}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9963984489440918}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3067416846752167}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9944589138031006}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.35103046894073486}
# {'word': 'face', 'tag': 'O', 'confidence': 0.99540114402771}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4757857322692871}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9964509010314941}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.26755601167678833}
# {'word': 'a', 'tag': 'O', 'confidence': 0.9954319000244141}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.304435133934021}
# {'word': 'deadly', 'tag': 'O', 'confidence': 0.9950351715087891}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5205543041229248}
# {'word': 'insurgency', 'tag': 'O', 'confidence': 0.9891741275787354}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4463978409767151}
# {'word': 'that', 'tag': 'O', 'confidence': 0.9965707063674927}
# {'word': 'WDT', 'tag': 'B-org', 'confidence': 0.4662131667137146}
# {'word': 'has', 'tag': 'O', 'confidence': 0.9960267543792725}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5148491859436035}
# {'word': 'killed', 'tag': 'O', 'confidence': 0.9964841604232788}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5125483870506287}
# {'word': 'more', 'tag': 'O', 'confidence': 0.9945896863937378}
# {'word': 'JJR', 'tag': 'B-org', 'confidence': 0.44536182284355164}
# {'word': 'than', 'tag': 'O', 'confidence': 0.9961385130882263}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.6866758465766907}
# {'word': '100', 'tag': 'O', 'confidence': 0.9879385828971863}
# {'word': 'CD', 'tag': 'O', 'confidence': 0.846950352191925}
# {'word': 'Iraqis', 'tag': 'B-gpe', 'confidence': 0.49466148018836975}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.3068951964378357}
# {'word': 'over', 'tag': 'O', 'confidence': 0.9939683675765991}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.25377658009529114}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9933732748031616}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.2742997705936432}
# {'word': 'past', 'tag': 'O', 'confidence': 0.9336758852005005}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.3573148548603058}
# {'word': 'week', 'tag': 'O', 'confidence': 0.9572945833206177}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4017498791217804}
# {'word': 'alone', 'tag': 'O', 'confidence': 0.9918036460876465}
# {'word': 'RB', 'tag': 'B-org', 'confidence': 0.36346015334129333}
# {'word': '.', 'tag': 'O', 'confidence': 0.8715413212776184}
# {'word': '.', 'tag': 'O', 'confidence': 0.9854565262794495}
# {'word': 'Ms.', 'tag': 'B-per', 'confidence': 0.821878969669342}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.30909067392349243}
# {'word': 'Rice', 'tag': 'I-per', 'confidence': 0.3308408558368683}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.39721277356147766}
# {'word': 'will', 'tag': 'O', 'confidence': 0.9956440925598145}
# {'word': 'MD', 'tag': 'O', 'confidence': 0.9697568416595459}
# {'word': 'travel', 'tag': 'O', 'confidence': 0.9957935810089111}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.5295844674110413}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9956077933311462}
# {'word': 'TO', 'tag': 'B-org', 'confidence': 0.27784860134124756}
# {'word': 'India', 'tag': 'B-geo', 'confidence': 0.5489382147789001}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3782365024089813}
# {'word': ',', 'tag': 'O', 'confidence': 0.9914029240608215}
# {'word': ',', 'tag': 'O', 'confidence': 0.9950509667396545}
# {'word': 'Pakistan', 'tag': 'B-geo', 'confidence': 0.72397381067276}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3962913453578949}
# {'word': ',', 'tag': 'O', 'confidence': 0.9894055724143982}
# {'word': ',', 'tag': 'O', 'confidence': 0.9947252869606018}
# {'word': 'Afghanistan', 'tag': 'B-geo', 'confidence': 0.7880181670188904}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3950865566730499}
# {'word': ',', 'tag': 'O', 'confidence': 0.9885454773902893}
# {'word': ',', 'tag': 'O', 'confidence': 0.9940871000289917}
# {'word': 'Japan', 'tag': 'B-geo', 'confidence': 0.7359994053840637}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.35832467675209045}
# {'word': ',', 'tag': 'O', 'confidence': 0.9902517795562744}
# {'word': ',', 'tag': 'O', 'confidence': 0.9945929646492004}
# {'word': 'South', 'tag': 'B-geo', 'confidence': 0.4908984899520874}
# {'word': 'NNP', 'tag': 'I-org', 'confidence': 0.3047998547554016}
# {'word': 'Korea', 'tag': 'B-geo', 'confidence': 0.6312592029571533}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3844960927963257}
# {'word': 'and', 'tag': 'O', 'confidence': 0.9915063977241516}
# {'word': 'CC', 'tag': 'B-org', 'confidence': 0.3522137403488159}
# {'word': 'China', 'tag': 'B-geo', 'confidence': 0.6124875545501709}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.34195005893707275}
# {'word': 'before', 'tag': 'O', 'confidence': 0.9965488314628601}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.22954927384853363}
# {'word': 'returning', 'tag': 'O', 'confidence': 0.9954511523246765}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.5342559814453125}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9965119957923889}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.36248964071273804}
# {'word': 'Washington', 'tag': 'B-geo', 'confidence': 0.7068175673484802}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.32580864429473877}
# {'word': 'on', 'tag': 'O', 'confidence': 0.9922658801078796}
# {'word': 'IN', 'tag': 'B-tim', 'confidence': 0.2847042381763458}
# {'word': 'March', 'tag': 'B-tim', 'confidence': 0.8324776291847229}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.38295260071754456}
# {'word': '21', 'tag': 'O', 'confidence': 0.21615181863307953}
# {'word': 'CD', 'tag': 'O', 'confidence': 0.26096999645233154}
# {'word': '.', 'tag': 'O', 'confidence': 0.9720690846443176}
# {'word': '.', 'tag': 'O', 'confidence': 0.9937906861305237}
# {'word': 'The', 'tag': 'O', 'confidence': 0.9941452741622925}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.5155404806137085}
# {'word': 'People', 'tag': 'I-org', 'confidence': 0.5194173455238342}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.4168700575828552}
# {'word': "'s", 'tag': 'O', 'confidence': 0.9912962913513184}
# {'word': 'POS', 'tag': 'B-org', 'confidence': 0.5120881199836731}
# {'word': 'Liberation', 'tag': 'I-org', 'confidence': 0.5897521376609802}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.404941588640213}
# {'word': 'Army', 'tag': 'I-org', 'confidence': 0.5332038402557373}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.45498767495155334}
# {'word': 'Daily', 'tag': 'I-org', 'confidence': 0.523371696472168}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.4816017746925354}
# {'word': 'newspaper', 'tag': 'O', 'confidence': 0.9797464609146118}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5175639390945435}
# {'word': 'said', 'tag': 'O', 'confidence': 0.9972701668739319}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.5816839337348938}
# {'word': 'Saturday', 'tag': 'B-tim', 'confidence': 0.9139050841331482}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.44920119643211365}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9977372884750366}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.40493515133857727}
# {'word': '2.3-million-strong', 'tag': 'O', 'confidence': 0.968758761882782}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5698752999305725}
# {'word': 'army', 'tag': 'O', 'confidence': 0.9935012459754944}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4863794147968292}
# {'word': 'should', 'tag': 'O', 'confidence': 0.9969037175178528}
# {'word': 'MD', 'tag': 'O', 'confidence': 0.8475167155265808}
# {'word': 'make', 'tag': 'O', 'confidence': 0.9974838495254517}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.5887296795845032}
# {'word': 'urgent', 'tag': 'O', 'confidence': 0.989522397518158}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5617271065711975}
# {'word': 'plans', 'tag': 'O', 'confidence': 0.99077308177948}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.5542618036270142}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9971359968185425}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.9909107089042664}
# {'word': 'detect', 'tag': 'O', 'confidence': 0.9967711567878723}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.5243914127349854}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9956437349319458}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.4111274480819702}
# {'word': 'virus', 'tag': 'O', 'confidence': 0.9882193803787231}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4912789762020111}
# {'word': 'and', 'tag': 'O', 'confidence': 0.9955969452857971}
# {'word': 'CC', 'tag': 'O', 'confidence': 0.9734464883804321}
# {'word': 'stop', 'tag': 'O', 'confidence': 0.9958606362342834}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.6143797636032104}
# {'word': 'its', 'tag': 'O', 'confidence': 0.995326042175293}
# {'word': 'PRP', 'tag': 'O', 'confidence': 0.7866051197052002}
# {'word': '$', 'tag': 'O', 'confidence': 0.9923790693283081}
# {'word': 'spread', 'tag': 'O', 'confidence': 0.9966555833816528}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.38551267981529236}
# {'word': '.', 'tag': 'O', 'confidence': 0.9948464632034302}
# {'word': '.', 'tag': 'O', 'confidence': 0.9949892163276672}
# {'word': 'The', 'tag': 'O', 'confidence': 0.9967674016952515}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.4987953305244446}
# {'word': 'Saudi', 'tag': 'B-gpe', 'confidence': 0.36578741669654846}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.40817421674728394}
# {'word': 'government', 'tag': 'O', 'confidence': 0.9863483905792236}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5181759595870972}
# {'word': 'launched', 'tag': 'O', 'confidence': 0.9971708655357361}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.5768173336982727}
# {'word': 'an', 'tag': 'O', 'confidence': 0.9965502023696899}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.43858566880226135}
# {'word': 'aggressive', 'tag': 'O', 'confidence': 0.9953858256340027}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.610497236251831}
# {'word': 'anti-terrorism', 'tag': 'O', 'confidence': 0.9946334362030029}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5255035161972046}
# {'word': 'campaign', 'tag': 'O', 'confidence': 0.9964895844459534}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4916703402996063}
# {'word': 'after', 'tag': 'O', 'confidence': 0.9967830181121826}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.4333728849887848}
# {'word': 'al-Qaida', 'tag': 'I-org', 'confidence': 0.3914572298526764}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.44323983788490295}
# {'word': 'militants', 'tag': 'O', 'confidence': 0.9948051571846008}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.5218603610992432}
# {'word': 'launched', 'tag': 'O', 'confidence': 0.9972055554389954}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.5557875633239746}
# {'word': 'dramatic', 'tag': 'O', 'confidence': 0.9971423745155334}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5638148784637451}
# {'word': 'terrorist', 'tag': 'O', 'confidence': 0.9934968948364258}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5998163819313049}
# {'word': 'attacks', 'tag': 'O', 'confidence': 0.9967310428619385}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.5333163142204285}
# {'word': 'against', 'tag': 'O', 'confidence': 0.9974685907363892}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.37272679805755615}
# {'word': 'Western', 'tag': 'O', 'confidence': 0.4500274658203125}
# {'word': 'JJ', 'tag': 'I-org', 'confidence': 0.4097636342048645}
# {'word': 'targets', 'tag': 'O', 'confidence': 0.9959671497344971}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.49623924493789673}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9926406741142273}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.2603425979614258}
# {'word': '2003', 'tag': 'B-tim', 'confidence': 0.4112340807914734}
# {'word': 'CD', 'tag': 'B-geo', 'confidence': 0.22402431070804596}
# {'word': '.', 'tag': 'O', 'confidence': 0.8124872446060181}
# {'word': '.', 'tag': 'O', 'confidence': 0.992760181427002}
# {'word': 'Their', 'tag': 'O', 'confidence': 0.9973658919334412}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.37915942072868347}
# {'word': '$', 'tag': 'O', 'confidence': 0.990525484085083}
# {'word': 'deaths', 'tag': 'O', 'confidence': 0.9969345331192017}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.43193116784095764}
# {'word': 'bring', 'tag': 'O', 'confidence': 0.9971485733985901}
# {'word': 'VBP', 'tag': 'B-org', 'confidence': 0.5387141704559326}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9970236420631409}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.9349699020385742}
# {'word': 'at', 'tag': 'O', 'confidence': 0.9970597624778748}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.8385947942733765}
# {'word': 'least', 'tag': 'O', 'confidence': 0.9956851005554199}
# {'word': 'JJS', 'tag': 'B-org', 'confidence': 0.45470529794692993}
# {'word': '10', 'tag': 'O', 'confidence': 0.9774729013442993}
# {'word': 'CD', 'tag': 'O', 'confidence': 0.8073722124099731}
# {'word': 'the', 'tag': 'O', 'confidence': 0.996637225151062}
# {'word': 'DT', 'tag': 'O', 'confidence': 0.8513144850730896}
# {'word': 'number', 'tag': 'O', 'confidence': 0.9965096116065979}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.3547753095626831}
# {'word': 'of', 'tag': 'O', 'confidence': 0.997014045715332}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.31929534673690796}
# {'word': 'coalition', 'tag': 'O', 'confidence': 0.9948617815971375}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4969123601913452}
# {'word': 'troops', 'tag': 'O', 'confidence': 0.996588945388794}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.4098236858844757}
# {'word': 'killed', 'tag': 'O', 'confidence': 0.997286319732666}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5127990245819092}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9958692193031311}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.20782031118869781}
# {'word': 'recent', 'tag': 'O', 'confidence': 0.9161059260368347}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.40616142749786377}
# {'word': 'days', 'tag': 'O', 'confidence': 0.9834960699081421}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.5443866848945618}
# {'word': '.', 'tag': 'O', 'confidence': 0.9776541590690613}
# {'word': '.', 'tag': 'O', 'confidence': 0.9946786165237427}
# {'word': 'Mr.', 'tag': 'B-per', 'confidence': 0.9333240985870361}
# {'word': 'NNP', 'tag': 'I-per', 'confidence': 0.5202405452728271}
# {'word': 'Haradinaj', 'tag': 'I-per', 'confidence': 0.7488832473754883}
# {'word': 'NNP', 'tag': 'I-per', 'confidence': 0.2749378979206085}
# {'word': 'has', 'tag': 'O', 'confidence': 0.9959359169006348}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.47707733511924744}
# {'word': 'insisted', 'tag': 'O', 'confidence': 0.9973424077033997}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5573850870132446}
# {'word': 'his', 'tag': 'O', 'confidence': 0.9968609809875488}
# {'word': 'PRP', 'tag': 'O', 'confidence': 0.7564533352851868}
# {'word': '$', 'tag': 'O', 'confidence': 0.9868476986885071}
# {'word': 'actions', 'tag': 'O', 'confidence': 0.9967635869979858}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.4948055148124695}
# {'word': 'were', 'tag': 'O', 'confidence': 0.9972570538520813}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.5403830409049988}
# {'word': 'consistent', 'tag': 'O', 'confidence': 0.9957570433616638}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.561231255531311}
# {'word': 'with', 'tag': 'O', 'confidence': 0.9962407350540161}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.33676138520240784}
# {'word': 'international', 'tag': 'O', 'confidence': 0.9899039268493652}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.49704962968826294}
# {'word': 'law', 'tag': 'O', 'confidence': 0.9792832732200623}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5237179398536682}
# {'word': '.', 'tag': 'O', 'confidence': 0.9744218587875366}
# {'word': '.', 'tag': 'O', 'confidence': 0.9945276379585266}
# {'word': 'A', 'tag': 'O', 'confidence': 0.9958678483963013}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.5200207233428955}
# {'word': 'Taliban', 'tag': 'I-org', 'confidence': 0.34170299768447876}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.38090598583221436}
# {'word': 'spokesman', 'tag': 'O', 'confidence': 0.9938939213752747}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4699748158454895}
# {'word': 'earlier', 'tag': 'O', 'confidence': 0.9949323534965515}
# {'word': 'RB', 'tag': 'O', 'confidence': 0.3669668138027191}
# {'word': 'denied', 'tag': 'O', 'confidence': 0.9974519610404968}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.6073659658432007}
# {'word': 'responsibility', 'tag': 'O', 'confidence': 0.996174693107605}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5016629695892334}
# {'word': 'for', 'tag': 'O', 'confidence': 0.9973306655883789}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.3790813386440277}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9917973279953003}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.3856251537799835}
# {'word': 'attack', 'tag': 'O', 'confidence': 0.9952945113182068}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5151364803314209}
# {'word': '.', 'tag': 'O', 'confidence': 0.9898125529289246}
# {'word': '.', 'tag': 'O', 'confidence': 0.9945346117019653}
# {'word': 'South', 'tag': 'B-geo', 'confidence': 0.2856934070587158}
# {'word': 'JJ', 'tag': 'I-org', 'confidence': 0.4120941758155823}
# {'word': 'African', 'tag': 'B-gpe', 'confidence': 0.22587458789348602}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.3422049283981323}
# {'word': 'health', 'tag': 'O', 'confidence': 0.9903289079666138}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4685092270374298}
# {'word': 'officials', 'tag': 'O', 'confidence': 0.995320737361908}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.4299156963825226}
# {'word': 'say', 'tag': 'O', 'confidence': 0.9971062541007996}
# {'word': 'VBP', 'tag': 'B-org', 'confidence': 0.4796271026134491}
# {'word': 'they', 'tag': 'O', 'confidence': 0.996468186378479}
# {'word': 'PRP', 'tag': 'O', 'confidence': 0.38720330595970154}
# {'word': 'have', 'tag': 'O', 'confidence': 0.9973952770233154}
# {'word': 'VBP', 'tag': 'B-org', 'confidence': 0.4041255712509155}
# {'word': 'confirmed', 'tag': 'O', 'confidence': 0.997223973274231}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.40796464681625366}
# {'word': 'six', 'tag': 'O', 'confidence': 0.9953669309616089}
# {'word': 'CD', 'tag': 'O', 'confidence': 0.9872103929519653}
# {'word': 'new', 'tag': 'O', 'confidence': 0.9965439438819885}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.31612667441368103}
# {'word': 'cases', 'tag': 'O', 'confidence': 0.996604323387146}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.3191296458244324}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9973188042640686}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.6550964117050171}
# {'word': 'a', 'tag': 'O', 'confidence': 0.9958637952804565}
# {'word': 'DT', 'tag': 'O', 'confidence': 0.75019770860672}
# {'word': 'deadly', 'tag': 'O', 'confidence': 0.9958804845809937}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.46060484647750854}
# {'word': 'and', 'tag': 'O', 'confidence': 0.9963768124580383}
# {'word': 'CC', 'tag': 'O', 'confidence': 0.9644217491149902}
# {'word': 'extremely', 'tag': 'O', 'confidence': 0.9915277361869812}
# {'word': 'RB', 'tag': 'O', 'confidence': 0.8426291942596436}
# {'word': 'drug-resistant', 'tag': 'O', 'confidence': 0.9920138716697693}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.4594016969203949}
# {'word': 'strain', 'tag': 'O', 'confidence': 0.994716465473175}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.42399632930755615}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9966471791267395}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.44015294313430786}
# {'word': 'tuberculosis', 'tag': 'O', 'confidence': 0.9676161408424377}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.2947402894496918}
# {'word': '.', 'tag': 'O', 'confidence': 0.9936262369155884}
# {'word': '.', 'tag': 'O', 'confidence': 0.9957005381584167}
# {'word': 'The', 'tag': 'O', 'confidence': 0.9967987537384033}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.49285268783569336}
# {'word': 'IAEA', 'tag': 'I-org', 'confidence': 0.3141137361526489}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.36850300431251526}
# {'word': 'has', 'tag': 'O', 'confidence': 0.996953010559082}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5833447575569153}
# {'word': 'been', 'tag': 'O', 'confidence': 0.9966973066329956}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5326459407806396}
# {'word': 'pressing', 'tag': 'O', 'confidence': 0.9963297247886658}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.5283804535865784}
# {'word': 'Iran', 'tag': 'B-geo', 'confidence': 0.5553445219993591}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.32257550954818726}
# {'word': 'for', 'tag': 'O', 'confidence': 0.9963920712471008}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.34181055426597595}
# {'word': 'months', 'tag': 'O', 'confidence': 0.9871943593025208}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.31491583585739136}
# {'word': 'for', 'tag': 'O', 'confidence': 0.9969683289527893}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.7537678480148315}
# {'word': 'access', 'tag': 'O', 'confidence': 0.9941921830177307}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4253416359424591}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9966281056404114}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.9842048287391663}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9957197308540344}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.36476173996925354}
# {'word': 'military', 'tag': 'O', 'confidence': 0.9916577935218811}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5259889364242554}
# {'word': 'site', 'tag': 'O', 'confidence': 0.9920072555541992}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.501359224319458}
# {'word': ',', 'tag': 'O', 'confidence': 0.9943842887878418}
# {'word': ',', 'tag': 'O', 'confidence': 0.9968219995498657}
# {'word': 'located', 'tag': 'O', 'confidence': 0.9969434142112732}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5413740873336792}
# {'word': 'about', 'tag': 'O', 'confidence': 0.9956647753715515}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.7532147169113159}
# {'word': '30', 'tag': 'O', 'confidence': 0.933830201625824}
# {'word': 'CD', 'tag': 'O', 'confidence': 0.9487647414207458}
# {'word': 'kilometers', 'tag': 'O', 'confidence': 0.9936238527297974}
# {'word': 'NNS', 'tag': 'O', 'confidence': 0.48918837308883667}
# {'word': 'southeast', 'tag': 'O', 'confidence': 0.9933833479881287}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.3772008717060089}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9954497218132019}
# {'word': 'IN', 'tag': 'B-geo', 'confidence': 0.3022276759147644}
# {'word': 'Tehran', 'tag': 'B-geo', 'confidence': 0.6873616576194763}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.32399463653564453}
# {'word': '.', 'tag': 'O', 'confidence': 0.9907467365264893}
# {'word': '.', 'tag': 'O', 'confidence': 0.9946175217628479}
# {'word': 'He', 'tag': 'O', 'confidence': 0.9958637952804565}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.5666052103042603}
# {'word': 'has', 'tag': 'O', 'confidence': 0.9957413673400879}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5068404078483582}
# {'word': ',', 'tag': 'O', 'confidence': 0.993501603603363}
# {'word': ',', 'tag': 'O', 'confidence': 0.995779275894165}
# {'word': 'however', 'tag': 'O', 'confidence': 0.9958480596542358}
# {'word': 'RB', 'tag': 'O', 'confidence': 0.26757189631462097}
# {'word': ',', 'tag': 'O', 'confidence': 0.9932088255882263}
# {'word': ',', 'tag': 'O', 'confidence': 0.9971091151237488}
# {'word': 'appeared', 'tag': 'O', 'confidence': 0.9972848892211914}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5098093748092651}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9962840676307678}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.3030213415622711}
# {'word': 'videos', 'tag': 'O', 'confidence': 0.9956667423248291}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.4861368238925934}
# {'word': 'and', 'tag': 'O', 'confidence': 0.9931238293647766}
# {'word': 'CC', 'tag': 'O', 'confidence': 0.9780916571617126}
# {'word': 'photographs', 'tag': 'O', 'confidence': 0.995612621307373}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.45732149481773376}
# {'word': ',', 'tag': 'O', 'confidence': 0.9947346448898315}
# {'word': ',', 'tag': 'O', 'confidence': 0.9968036413192749}
# {'word': 'and', 'tag': 'O', 'confidence': 0.997002899646759}
# {'word': 'CC', 'tag': 'O', 'confidence': 0.9928929209709167}
# {'word': 'articles', 'tag': 'O', 'confidence': 0.9967219233512878}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.4729541540145874}
# {'word': 'attributed', 'tag': 'O', 'confidence': 0.9965274930000305}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.4770996868610382}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9967553019523621}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.952181339263916}
# {'word': 'him', 'tag': 'O', 'confidence': 0.9941828846931458}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.47662436962127686}
# {'word': 'have', 'tag': 'O', 'confidence': 0.9969404935836792}
# {'word': 'VBP', 'tag': 'B-org', 'confidence': 0.4253283739089966}
# {'word': 'been', 'tag': 'O', 'confidence': 0.9956766963005066}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.4742248058319092}
# {'word': 'published', 'tag': 'O', 'confidence': 0.995684027671814}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.46670854091644287}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9951299428939819}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.18822155892848969}
# {'word': 'the', 'tag': 'O', 'confidence': 0.989051103591919}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.4089691638946533}
# {'word': 'state-run', 'tag': 'O', 'confidence': 0.9848344326019287}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5028451085090637}
# {'word': 'media', 'tag': 'O', 'confidence': 0.9746478796005249}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.4996725618839264}
# {'word': '.', 'tag': 'O', 'confidence': 0.9675474166870117}
# {'word': '.', 'tag': 'O', 'confidence': 0.9918396472930908}
# {'word': 'The', 'tag': 'O', 'confidence': 0.996562659740448}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.4787452220916748}
# {'word': 'group', 'tag': 'O', 'confidence': 0.9716314077377319}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5173273086547852}
# {'word': 'includes', 'tag': 'O', 'confidence': 0.9964531660079956}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5977820754051208}
# {'word': 'personnel', 'tag': 'O', 'confidence': 0.9968904852867126}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.49044519662857056}
# {'word': 'who', 'tag': 'O', 'confidence': 0.9970037341117859}
# {'word': 'WP', 'tag': 'O', 'confidence': 0.584246814250946}
# {'word': 'were', 'tag': 'O', 'confidence': 0.9937838315963745}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.5703190565109253}
# {'word': 'scheduled', 'tag': 'O', 'confidence': 0.9973168969154358}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5327839255332947}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9971032738685608}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.9861894249916077}
# {'word': 'rotate', 'tag': 'O', 'confidence': 0.9970537424087524}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.4144655168056488}
# {'word': 'home', 'tag': 'O', 'confidence': 0.9657947421073914}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4221123456954956}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9900376796722412}
# {'word': 'IN', 'tag': 'B-tim', 'confidence': 0.26077979803085327}
# {'word': 'September', 'tag': 'B-tim', 'confidence': 0.8023163080215454}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.43030038475990295}
# {'word': 'and', 'tag': 'O', 'confidence': 0.9959800243377686}
# {'word': 'CC', 'tag': 'O', 'confidence': 0.9747913479804993}
# {'word': 'others', 'tag': 'O', 'confidence': 0.9942620992660522}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.48821818828582764}
# {'word': 'whose', 'tag': 'O', 'confidence': 0.9965918064117432}
# {'word': 'WP', 'tag': 'B-org', 'confidence': 0.4085983335971832}
# {'word': '$', 'tag': 'O', 'confidence': 0.9846829771995544}
# {'word': 'deployments', 'tag': 'O', 'confidence': 0.9961211085319519}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.5491790175437927}
# {'word': 'would', 'tag': 'O', 'confidence': 0.9953784942626953}
# {'word': 'MD', 'tag': 'O', 'confidence': 0.8172309994697571}
# {'word': 'be', 'tag': 'O', 'confidence': 0.9880181550979614}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.569638192653656}
# {'word': 'cut', 'tag': 'O', 'confidence': 0.9915094375610352}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.5462383031845093}
# {'word': 'short', 'tag': 'O', 'confidence': 0.9956492781639099}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.44466081261634827}
# {'word': '.', 'tag': 'O', 'confidence': 0.9758776426315308}
# {'word': '.', 'tag': 'O', 'confidence': 0.9938071370124817}
# {'word': 'International', 'tag': 'O', 'confidence': 0.9451860189437866}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.49048298597335815}
# {'word': 'observers', 'tag': 'O', 'confidence': 0.9938772320747375}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.5314229726791382}
# {'word': 'say', 'tag': 'O', 'confidence': 0.9970344305038452}
# {'word': 'VBP', 'tag': 'B-org', 'confidence': 0.543840229511261}
# {'word': 'there', 'tag': 'O', 'confidence': 0.9963765740394592}
# {'word': 'EX', 'tag': 'B-org', 'confidence': 0.5359699726104736}
# {'word': 'is', 'tag': 'O', 'confidence': 0.9944656491279602}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5901215076446533}
# {'word': 'no', 'tag': 'O', 'confidence': 0.9967183470726013}
# {'word': 'DT', 'tag': 'O', 'confidence': 0.6103480458259583}
# {'word': 'evidence', 'tag': 'O', 'confidence': 0.9966920614242554}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.41093671321868896}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9972364902496338}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.449630469083786}
# {'word': 'widespread', 'tag': 'O', 'confidence': 0.9969373941421509}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5844342708587646}
# {'word': 'fraud', 'tag': 'O', 'confidence': 0.995500385761261}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.43126559257507324}
# {'word': 'in', 'tag': 'O', 'confidence': 0.9968571662902832}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3188675343990326}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9953715205192566}
# {'word': 'DT', 'tag': 'O', 'confidence': 0.3639746904373169}
# {'word': 'run-off', 'tag': 'O', 'confidence': 0.9939066767692566}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4643736481666565}
# {'word': '.', 'tag': 'O', 'confidence': 0.9944039583206177}
# {'word': '.', 'tag': 'O', 'confidence': 0.9951451420783997}
# {'word': 'The', 'tag': 'O', 'confidence': 0.99601149559021}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.5141451358795166}
# {'word': 'secretary-general', 'tag': 'O', 'confidence': 0.963161826133728}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.38904592394828796}
# {'word': 'will', 'tag': 'O', 'confidence': 0.9955635070800781}
# {'word': 'MD', 'tag': 'O', 'confidence': 0.7029862999916077}
# {'word': 'also', 'tag': 'O', 'confidence': 0.9953932762145996}
# {'word': 'RB', 'tag': 'O', 'confidence': 0.8704667687416077}
# {'word': 'be', 'tag': 'O', 'confidence': 0.9932492971420288}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.49687904119491577}
# {'word': 'traveling', 'tag': 'O', 'confidence': 0.9960881471633911}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.5616782307624817}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9969910383224487}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.9686482548713684}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9960732460021973}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.4083087146282196}
# {'word': 'Darfur', 'tag': 'B-geo', 'confidence': 0.4961143434047699}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3957778513431549}
# {'word': 'region', 'tag': 'O', 'confidence': 0.9896654486656189}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5018753409385681}
# {'word': 'himself', 'tag': 'O', 'confidence': 0.9952991008758545}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.4489183723926544}
# {'word': 'and', 'tag': 'O', 'confidence': 0.9952971339225769}
# {'word': 'CC', 'tag': 'O', 'confidence': 0.941479504108429}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9961977601051331}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.957697331905365}
# {'word': 'Sudan', 'tag': 'B-geo', 'confidence': 0.685876190662384}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.36526164412498474}
# {'word': "'s", 'tag': 'O', 'confidence': 0.994682252407074}
# {'word': 'POS', 'tag': 'O', 'confidence': 0.4067719876766205}
# {'word': 'southern', 'tag': 'O', 'confidence': 0.9940471649169922}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5544870495796204}
# {'word': 'town', 'tag': 'O', 'confidence': 0.9825683832168579}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.49973514676094055}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9939642548561096}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.4167301654815674}
# {'word': 'Rumbek', 'tag': 'I-org', 'confidence': 0.26235732436180115}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3707432150840759}
# {'word': ',', 'tag': 'O', 'confidence': 0.993536114692688}
# {'word': ',', 'tag': 'O', 'confidence': 0.9963619112968445}
# {'word': 'where', 'tag': 'O', 'confidence': 0.9965527057647705}
# {'word': 'WRB', 'tag': 'B-org', 'confidence': 0.5716797709465027}
# {'word': 'he', 'tag': 'O', 'confidence': 0.993392288684845}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.49955829977989197}
# {'word': 'will', 'tag': 'O', 'confidence': 0.99657142162323}
# {'word': 'MD', 'tag': 'O', 'confidence': 0.9041189551353455}
# {'word': 'examine', 'tag': 'O', 'confidence': 0.9966461062431335}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.4197032153606415}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9915755391120911}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.419624924659729}
# {'word': 'peace', 'tag': 'O', 'confidence': 0.9897330403327942}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.4853478670120239}
# {'word': 'process', 'tag': 'O', 'confidence': 0.9883511662483215}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5110140442848206}
# {'word': '.', 'tag': 'O', 'confidence': 0.9905840158462524}
# {'word': '.', 'tag': 'O', 'confidence': 0.9937856197357178}
# {'word': 'China', 'tag': 'B-geo', 'confidence': 0.6765338182449341}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.4053843915462494}
# {'word': "'s", 'tag': 'O', 'confidence': 0.9895884990692139}
# {'word': 'POS', 'tag': 'B-org', 'confidence': 0.468449205160141}
# {'word': 'Commerce', 'tag': 'I-org', 'confidence': 0.6292380690574646}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3421333134174347}
# {'word': 'Ministry', 'tag': 'I-org', 'confidence': 0.4891785681247711}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.44747066497802734}
# {'word': 'says', 'tag': 'O', 'confidence': 0.9969393014907837}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5974773168563843}
# {'word': 'major', 'tag': 'O', 'confidence': 0.9966687560081482}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5062781572341919}
# {'word': 'differences', 'tag': 'O', 'confidence': 0.9963805079460144}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.3800160884857178}
# {'word': 'remain', 'tag': 'O', 'confidence': 0.9970302581787109}
# {'word': 'VBP', 'tag': 'B-org', 'confidence': 0.35194727778434753}
# {'word': 'between', 'tag': 'O', 'confidence': 0.9959962368011475}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3072192370891571}
# {'word': 'Beijing', 'tag': 'B-geo', 'confidence': 0.7021952867507935}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.323853462934494}
# {'word': 'and', 'tag': 'O', 'confidence': 0.9939968585968018}
# {'word': 'CC', 'tag': 'O', 'confidence': 0.31648629903793335}
# {'word': 'Washington', 'tag': 'B-geo', 'confidence': 0.5492017865180969}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.34262242913246155}
# {'word': 'over', 'tag': 'O', 'confidence': 0.9968608617782593}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.26124298572540283}
# {'word': 'textile', 'tag': 'O', 'confidence': 0.9936337471008301}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.38441789150238037}
# {'word': 'exports', 'tag': 'O', 'confidence': 0.9933070540428162}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.33307695388793945}
# {'word': 'after', 'tag': 'O', 'confidence': 0.991915762424469}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.2622607946395874}
# {'word': 'two', 'tag': 'O', 'confidence': 0.5248722434043884}
# {'word': 'CD', 'tag': 'O', 'confidence': 0.832415759563446}
# {'word': 'days', 'tag': 'O', 'confidence': 0.9830780625343323}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.3952859044075012}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9958122372627258}
# ...
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.43743088841438293}
# {'word': 'off', 'tag': 'O', 'confidence': 0.9906766414642334}
# {'word': 'RP', 'tag': 'B-org', 'confidence': 0.42830413579940796}
# {'word': 'their', 'tag': 'O', 'confidence': 0.9934408068656921}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.40026435256004333}
# {'word': '$', 'tag': 'O', 'confidence': 0.984074592590332}
# {'word': 'tails', 'tag': 'O', 'confidence': 0.9942275285720825}
# {'word': 'NNS', 'tag': 'O', 'confidence': 0.27871230244636536}
# {'word': ',', 'tag': 'O', 'confidence': 0.9952186942100525}
# {'word': ',', 'tag': 'O', 'confidence': 0.994712769985199}
# {'word': 'saying', 'tag': 'O', 'confidence': 0.9959691762924194}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.46417418122291565}
# {'word': 'that', 'tag': 'O', 'confidence': 0.9959920048713684}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.28458768129348755}
# {'word': 'they', 'tag': 'O', 'confidence': 0.9930552840232849}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.3779284954071045}
# {'word': 'would', 'tag': 'O', 'confidence': 0.995635449886322}
# {'word': 'MD', 'tag': 'O', 'confidence': 0.48925289511680603}
# {'word': 'not', 'tag': 'O', 'confidence': 0.9923934936523438}
# {'word': 'RB', 'tag': 'B-org', 'confidence': 0.2309146672487259}
# {'word': 'only', 'tag': 'O', 'confidence': 0.9890775680541992}
# {'word': 'RB', 'tag': 'B-org', 'confidence': 0.2766128480434418}
# {'word': 'look', 'tag': 'O', 'confidence': 0.9929775595664978}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.47010645270347595}
# {'word': 'much', 'tag': 'O', 'confidence': 0.990679919719696}
# {'word': 'RB', 'tag': 'B-org', 'confidence': 0.26326459646224976}
# {'word': 'better', 'tag': 'O', 'confidence': 0.9920925498008728}
# {'word': 'JJR', 'tag': 'B-org', 'confidence': 0.3868982493877411}
# {'word': 'without', 'tag': 'O', 'confidence': 0.9930250644683838}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.24269767105579376}
# {'word': 'them', 'tag': 'O', 'confidence': 0.9866765737533569}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.4250161349773407}
# {'word': ',', 'tag': 'O', 'confidence': 0.9931140542030334}
# {'word': ',', 'tag': 'O', 'confidence': 0.9946913123130798}
# {'word': 'but', 'tag': 'O', 'confidence': 0.9946203231811523}
# {'word': 'CC', 'tag': 'O', 'confidence': 0.25799936056137085}
# {'word': 'that', 'tag': 'O', 'confidence': 0.9932291507720947}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.2937719225883484}
# {'word': 'they', 'tag': 'O', 'confidence': 0.9905010461807251}
# {'word': 'PRP', 'tag': 'B-org', 'confidence': 0.42269036173820496}
# {'word': 'would', 'tag': 'O', 'confidence': 0.9930056929588318}
# {'word': 'MD', 'tag': 'B-org', 'confidence': 0.22184300422668457}
# {'word': 'get', 'tag': 'O', 'confidence': 0.9955886602401733}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.46073925495147705}
# {'word': 'rid', 'tag': 'O', 'confidence': 0.988532304763794}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.4201330244541168}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9946030974388123}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.20558197796344757}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9942746758460999}
# {'word': 'DT', 'tag': 'O', 'confidence': 0.2945306599140167}
# {'word': 'weight', 'tag': 'O', 'confidence': 0.9897814989089966}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.24769361317157745}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9949316382408142}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.22639375925064087}
# {'word': 'the', 'tag': 'O', 'confidence': 0.9937005043029785}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.2211267054080963}
# {'word': 'brush', 'tag': 'O', 'confidence': 0.9910552501678467}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.2535322308540344}
# {'word': ',', 'tag': 'O', 'confidence': 0.9949561953544617}
# {'word': ',', 'tag': 'O', 'confidence': 0.9947049021720886}
# {'word': 'which', 'tag': 'O', 'confidence': 0.995731770992279}
# {'word': 'WDT', 'tag': 'O', 'confidence': 0.4655967950820923}
# {'word': 'was', 'tag': 'O', 'confidence': 0.9936770796775818}
# {'word': 'VBD', 'tag': 'B-org', 'confidence': 0.4323236346244812}
# {'word': 'a', 'tag': 'O', 'confidence': 0.9939384460449219}
# {'word': 'DT', 'tag': 'O', 'confidence': 0.2983216643333435}
# {'word': 'very', 'tag': 'O', 'confidence': 0.9936432838439941}
# {'word': 'RB', 'tag': 'O', 'confidence': 0.6460104584693909}
# {'word': 'great', 'tag': 'O', 'confidence': 0.9957749247550964}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.39604243636131287}
# {'word': 'inconvenience', 'tag': 'O', 'confidence': 0.9891151189804077}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.3045533299446106}
# {'word': '.', 'tag': 'O', 'confidence': 0.9949203133583069}
# {'word': '.', 'tag': 'O', 'confidence': 0.9947959780693054}
# {'word': 'The', 'tag': 'O', 'confidence': 0.9966412782669067}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.492618203163147}
# {'word': 'French-Colombian', 'tag': 'B-org', 'confidence': 0.29993999004364014}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.5300106406211853}
# {'word': 'politician', 'tag': 'O', 'confidence': 0.9810158610343933}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5401575565338135}
# {'word': 'has', 'tag': 'O', 'confidence': 0.9968587160110474}
# {'word': 'VBZ', 'tag': 'B-org', 'confidence': 0.5904155969619751}
# {'word': 'been', 'tag': 'O', 'confidence': 0.9966026544570923}
# {'word': 'VBN', 'tag': 'B-org', 'confidence': 0.588837742805481}
# {'word': 'on', 'tag': 'O', 'confidence': 0.9968562126159668}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3084340989589691}
# {'word': 'a', 'tag': 'O', 'confidence': 0.9958224296569824}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.31063616275787354}
# {'word': 'tour', 'tag': 'O', 'confidence': 0.9931324124336243}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5126602053642273}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9967195391654968}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.32023316621780396}
# {'word': 'South', 'tag': 'O', 'confidence': 0.5359687805175781}
# {'word': 'JJ', 'tag': 'I-org', 'confidence': 0.3854285180568695}
# {'word': 'American', 'tag': 'O', 'confidence': 0.6171684861183167}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.4046115279197693}
# {'word': 'countries', 'tag': 'O', 'confidence': 0.9872238636016846}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.41068634390830994}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9974729418754578}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.9907299876213074}
# {'word': 'solicit', 'tag': 'O', 'confidence': 0.9965853691101074}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.5154842138290405}
# {'word': 'regional', 'tag': 'O', 'confidence': 0.9724713563919067}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.48818954825401306}
# {'word': 'support', 'tag': 'O', 'confidence': 0.9960422515869141}
# {'word': 'NN', 'tag': 'B-org', 'confidence': 0.5393532514572144}
# {'word': 'for', 'tag': 'O', 'confidence': 0.99735426902771}
# {'word': 'IN', 'tag': 'O', 'confidence': 0.3707342743873596}
# {'word': 'persuading', 'tag': 'O', 'confidence': 0.9920956492424011}
# {'word': 'VBG', 'tag': 'B-org', 'confidence': 0.5496994853019714}
# {'word': 'rebels', 'tag': 'O', 'confidence': 0.995635449886322}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.46983206272125244}
# {'word': 'with', 'tag': 'O', 'confidence': 0.9962968230247498}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.3472251296043396}
# {'word': 'the', 'tag': 'O', 'confidence': 0.98667311668396}
# {'word': 'DT', 'tag': 'B-org', 'confidence': 0.5042961239814758}
# {'word': 'Revolutionary', 'tag': 'B-org', 'confidence': 0.319504052400589}
# {'word': 'JJ', 'tag': 'I-org', 'confidence': 0.3711037337779999}
# {'word': 'Armed', 'tag': 'I-org', 'confidence': 0.42095130681991577}
# {'word': 'JJ', 'tag': 'B-org', 'confidence': 0.40147870779037476}
# {'word': 'Forces', 'tag': 'I-org', 'confidence': 0.568501353263855}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.45529764890670776}
# {'word': 'of', 'tag': 'O', 'confidence': 0.9856504797935486}
# {'word': 'IN', 'tag': 'B-org', 'confidence': 0.4336775839328766}
# {'word': 'Colombia', 'tag': 'B-geo', 'confidence': 0.4990027844905853}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.3939903676509857}
# {'word': ',', 'tag': 'O', 'confidence': 0.9813530445098877}
# {'word': ',', 'tag': 'O', 'confidence': 0.9942110776901245}
# {'word': 'or', 'tag': 'O', 'confidence': 0.9915142059326172}
# {'word': 'CC', 'tag': 'B-org', 'confidence': 0.45203471183776855}
# {'word': 'FARC', 'tag': 'B-org', 'confidence': 0.3851223886013031}
# {'word': 'NNP', 'tag': 'B-org', 'confidence': 0.38600024580955505}
# {'word': ',', 'tag': 'O', 'confidence': 0.9911077618598938}
# {'word': ',', 'tag': 'O', 'confidence': 0.9954167604446411}
# {'word': 'to', 'tag': 'O', 'confidence': 0.9975712895393372}
# {'word': 'TO', 'tag': 'O', 'confidence': 0.9706729650497437}
# {'word': 'release', 'tag': 'O', 'confidence': 0.997063934803009}
# {'word': 'VB', 'tag': 'B-org', 'confidence': 0.5779396295547485}
# {'word': 'their', 'tag': 'O', 'confidence': 0.9960682392120361}
# {'word': 'PRP', 'tag': 'O', 'confidence': 0.4385874569416046}
# {'word': '$', 'tag': 'O', 'confidence': 0.986786961555481}
# {'word': 'captives', 'tag': 'O', 'confidence': 0.9965546131134033}
# {'word': 'NNS', 'tag': 'B-org', 'confidence': 0.45098623633384705}
# {'word': '.', 'tag': 'O', 'confidence': 0.9938057661056519}
# {'word': '.', 'tag': 'O', 'confidence': 0.994674801826477}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-fd99333af861> in <module>
#      18 with open(os.path.join(dataset, output_filename), "w") as wf:
#      19     for sentence in sentences:
# ---> 20         output = model.predict(sentence)
#      21         for prediction in output:
#      22             print(prediction)
#
# ~\Documents\CodingProjects\50.040-NLP-Sentiment-Analysis\data\bert.py in predict(self, text)
#      90         valid_ids = torch.tensor([valid_ids],dtype=torch.long,device=self.device)
#      91         with torch.no_grad():
# ---> 92             logits = self.model(input_ids, segment_ids, input_mask,valid_ids)
#      93         logits = F.softmax(logits,dim=2)
#      94         logits_label = torch.argmax(logits,dim=2)
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\Documents\CodingProjects\50.040-NLP-Sentiment-Analysis\data\bert.py in forward(self, input_ids, token_type_ids, attention_mask, valid_ids)
#      16
#      17     def forward(self, input_ids, token_type_ids=None, attention_mask=None, valid_ids=None):
# ---> 18         sequence_output = self.bert(input_ids, token_type_ids, attention_mask, head_mask=None)[0]
#      19         batch_size,max_len,feat_dim = sequence_output.shape
#      20         valid_output = torch.zeros(batch_size,max_len,feat_dim,dtype=torch.float32,device='cuda' if torch.cuda.is_available() else 'cpu')
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\pytorch_transformers\modeling_bert.py in forward(self, input_ids, token_type_ids, attention_mask, position_ids, head_mask)
#     708         encoder_outputs = self.encoder(embedding_output,
#     709                                        extended_attention_mask,
# --> 710                                        head_mask=head_mask)
#     711         sequence_output = encoder_outputs[0]
#     712         pooled_output = self.pooler(sequence_output)
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\pytorch_transformers\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask)
#     429                 all_hidden_states = all_hidden_states + (hidden_states,)
#     430
# --> 431             layer_outputs = layer_module(hidden_states, attention_mask, head_mask[i])
#     432             hidden_states = layer_outputs[0]
#     433
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\pytorch_transformers\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask)
#     407
#     408     def forward(self, hidden_states, attention_mask, head_mask=None):
# --> 409         attention_outputs = self.attention(hidden_states, attention_mask, head_mask)
#     410         attention_output = attention_outputs[0]
#     411         intermediate_output = self.intermediate(attention_output)
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\pytorch_transformers\modeling_bert.py in forward(self, input_tensor, attention_mask, head_mask)
#     364
#     365     def forward(self, input_tensor, attention_mask, head_mask=None):
# --> 366         self_outputs = self.self(input_tensor, attention_mask, head_mask)
#     367         attention_output = self.output(self_outputs[0], input_tensor)
#     368         outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\pytorch_transformers\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask)
#     285     def forward(self, hidden_states, attention_mask, head_mask=None):
#     286         mixed_query_layer = self.query(hidden_states)
# --> 287         mixed_key_layer = self.key(hidden_states)
#     288         mixed_value_layer = self.value(hidden_states)
#     289
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# ~\anaconda3\envs\nlp\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
# -> 1676         output = input.matmul(weight.t())
#    1677         if bias is not None:
#    1678             output += bias
#
# KeyboardInterrupt:

# %%
from conlleval2 import evaluate, evaluate_conll_file

def eval(pred,gold):
    f_pred = open(pred,encoding = 'utf-8')
    f_gold = open(gold,encoding = 'utf-8')
    data_pred = f_pred.readlines()
    data_gold = f_gold.readlines()
    gold_tags = list()
    pred_tags = list()
    print(data_pred[0])
    for sentence in range(len(data_pred)):
        words_pred = data_pred[sentence].strip().split(' ')    
        words_gold = data_gold[sentence].strip().split(' ')  
        if len(words_gold)==1:
            continue
        gold_tags.append(words_gold[1])
        pred_tags.append(words_pred[1])
    return gold_tags,pred_tags

g_tags, p_tags = eval(os.path.join(dataset, 'dev.p6.model.out'), os.path.join(dataset, 'dev.out'))
print(evaluate(g_tags,p_tags,verbose=True))
# Out:
# The O
#
# processed 2097 tokens with 236 phrases; found: 264 phrases; correct: 146.
# accuracy:  63.24%; (non-O)
# accuracy:  93.04%; precision:  55.30%; recall:  61.86%; FB1:  58.40
#               art: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#               eve: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#               geo: precision:  58.82%; recall:  70.59%; FB1:  64.17  102
#               gpe: precision:  81.82%; recall:  72.00%; FB1:  76.60  22
#               nat: precision:   0.00%; recall:   0.00%; FB1:   0.00  0
#               org: precision:  27.66%; recall:  37.14%; FB1:  31.71  47
#               per: precision:  63.33%; recall:  59.38%; FB1:  61.29  30
#               tim: precision:  57.14%; recall:  67.92%; FB1:  62.07  63
# (55.3030303030303, 61.86440677966102, 58.400000000000006)
